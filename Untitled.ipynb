# %%
import pandas as pd
df = pd.read_csv("data/9745_greatest_books_ever.csv")

display(print(f"\n\n\nTotal greatest books ever: 9744 || Total Book Data: {df.size}"))

df
# Out:
# Total greatest books ever: 9745 || Total Book Data: 662660
# None
#       Unnamed: 0     book_id                       title            author  \
# 0              0  13509957.0                   Charmeine       Emily Guido
# 1              1  17999935.0  Arsen: A Broken Love Story         Mia Asher
# 2              2  23367265.0              Immortal Reign     Morgan Rhodes
# 3              3     22080.0                   Westworld  Michael Crichton
# 4              4  50892338.0                  Legendborn       Tracy Deonn
# ...          ...         ...                         ...               ...
# 9740        9740    154332.0       Biographie de la faim    Amélie Nothomb
# 9741        9741     59836.0                    The Gift    Danielle Steel
# 9742        9742  13505670.0      Krampus: The Yule Lord              Brom
# 9743        9743  13151129.0               Earth Unaware  Orson Scott Card
# 9744        9744  17831617.0         Beautiful Bombshell  Christina Lauren
#
# ...
